# %% [markdown]
# # Music 108 Final
# ## Seiya Ono Spring 20

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from helper_code import *

# %% [markdown]
# ## Example Audio File

# %%
file_name = 'kai'
aud_file = audio_file(file_name + '.wav')
aud_file.info_dump()
# Out:
# File Name:      kai.wav
# Channels:       2
# Byte Depth:     2
# Sampling rate:  44100
# Frames:         269717

# %%
aud_file.graph_waveform()

# %% [markdown]
# ## Running Experiments

# %% [markdown]
# ### Acoustic Recording - Piano

# %%
file_name = 'kai'
list_file_names_kai = generate_wav_files(file_name)

# %%
run_experiments(3, list_file_names_kai, file_name)
# Out:
# File: kai_24bit_44.1kHz.wav Score: 0
# File: kai_24bit_22.05kHz.wav Score: 1
# File: kai_24bit_11.025kHz.wav Score: 0
# File: kai_16bit_44.1kHz.wav Score: 1
# File: kai_16bit_22.05kHz.wav Score: 1
# File: kai_16bit_11.025kHz.wav Score: 0

# %% [markdown]
# ### Electronic Recording - EDM

# %%
file_name = 'www'
list_file_names_www = generate_wav_files(file_name)
# Out:
# File Name:      www.wav
# Channels:       2
# Byte Depth:     2
# Sampling rate:  44100
# Frames:         360199

# %%
run_experiments(3, list_file_names_www, file_name)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     883             try:
# --> 884                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     885             except Exception:
#
# /usr/lib/python3.8/site-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     812         try:
# --> 813             msg_list = socket.recv_multipart(mode, copy=copy)
#     814         except zmq.ZMQError as e:
#
# /usr/lib/python3.8/site-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     474         """
# --> 475         parts = [self.recv(flags, copy=copy, track=track)]
#     476         # have first part already, only loop while more to receive
#
# ...

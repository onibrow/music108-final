# %% [markdown]
# # Music 108 Final
# ## Seiya Ono Spring 20

# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import wave, struct, math, random
import soundfile as sf
import numpy as np
import scipy
import scipy.io.wavfile as wavfile
from IPython.display import Audio
from helper_code import *

# %%
pastel = audio_file('pastel_24bit_44.1khz.wav')
pastel.info_dump()
# Out:
# File Name:      pastel_24bit_44.1khz.wav
# Channels:       2
# Byte Depth:     3
# Sampling rate:  44100
# Frames:         246502

# %%
pastel.load_data()
pastel.graph_waveform()
# Out:
# Generating 32 bit up scaled waveform...

# %%
pastel.save_clip('pastel_32bits_44.1kHz.wav')

# %%
pastel.down_sample(2, 'pastel_32bits_22.05kHz.wav')

# %%
pastel.down_sample(4, 'pastel_32bits_11.025kHz.wav')

# %%
#pastel.up_sample(2, 'pastel_32bits_88.2kHz.wav')

# %% [markdown]
# ## Resampling

# %%
pastel_32bits_441kHz    = audio_file('pastel_32bits_44.1kHz.wav')
pastel_32bits_441kHz.info_dump()
print()
pastel_32bits_2205kHz   = audio_file('pastel_32bits_22.05kHz.wav')
pastel_32bits_2205kHz.info_dump()
print()
pastel_32bits_11025kHz = audio_file('pastel_32bits_11.025kHz.wav')
pastel_32bits_11025kHz.info_dump()
# Out:
# File Name:      pastel_32bits_44.1kHz.wav
# Channels:       2
# Byte Depth:     4
# Sampling rate:  44100
# Frames:         246502
#
# File Name:      pastel_32bits_22.05kHz.wav
# Channels:       2
# Byte Depth:     4
# Sampling rate:  22050
# Frames:         123251
#
# File Name:      pastel_32bits_11.025kHz.wav
# Channels:       2
# Byte Depth:     4
# Sampling rate:  11025
# Frames:         61626
